# %%
import sympy as sy
import numpy as np
from sympy.functions import sin,cos, exp, log
import matplotlib.pyplot as plt

# %% [markdown]
# # Aufgabe 1

# %%
# Define the variable and the function to approximate
x = sy.Symbol('x')
f = (2*x+2)**(1/3)

# Factorial function
def factorial(n):
    if n <= 0:
        return 1
    else:
        return n*factorial(n-1)

# Taylor approximation at x0 of the function 'function'
def taylor(function,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (function.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# Plot results
def plot():
    x_lims = [-1,50]
    x1 = np.linspace(x_lims[0],x_lims[1],800)
    y1 = []
    # Approximate up until 10 starting from 1 and using steps of 2
    for j in range(0,4,1):
        func = taylor(f,3,j)
        print('Taylor expansion at n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label=str(j)+'. Ordnung')
        y1 = []
    # Plot the function to approximate (sine, in this case)
    plt.plot(x1,(2*x1+2)**(1/3),label='f(x)')
    plt.xlim(x_lims)
    plt.ylim([-10,10])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.savefig("Aufgabe_1.pdf")
    plt.show()

plot()
# Out:
# Taylor expansion at n=0 2.00000000000000
# Taylor expansion at n=1 0.166666666666667*x + 1.5
# Taylor expansion at n=2 0.166666666666667*x - 0.0138888888888889*(x - 3)**2 + 1.5
# Taylor expansion at n=3 0.166666666666667*x + 0.00192901234567901*(x - 3)**3 - 0.0138888888888889*(x - 3)**2 + 1.5

# %% [markdown]
# # Aufgabe 2

# %%
# Define the variable and the function to approximate
x = sy.Symbol('x')
f = sin(3*x)

# Factorial function
def factorial(n):
    if n <= 0:
        return 1
    else:
        return n*factorial(n-1)

# Taylor approximation at x0 of the function 'function'
def taylor(function,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (function.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# Plot results
def plot():
    x_lims = [-5,5]
    x1 = np.linspace(x_lims[0],x_lims[1],800)
    y1 = []
    # Approximate up until 10 starting from 1 and using steps of 2
    for j in range(1,8,2):
        func = taylor(f,0,j)
        print('Taylor expansion at n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label=str(j)+'. Ordnung')
        y1 = []
    # Plot the function to approximate (sine, in this case)
    plt.plot(x1,np.sin(3*x1),label='sin(x)')
    plt.xlim(x_lims)
    plt.ylim([-5,5])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.savefig("Aufgabe_2a.pdf")
    plt.show()

plot()
# Out:
# Taylor expansion at n=1 3*x
# Taylor expansion at n=3 -9*x**3/2 + 3*x
# Taylor expansion at n=5 81*x**5/40 - 9*x**3/2 + 3*x
# Taylor expansion at n=7 -243*x**7/560 + 81*x**5/40 - 9*x**3/2 + 3*x

# %%
# Define the variable and the function to approximate
x = sy.Symbol('x')
f = (1+x)**(1/2)

# Factorial function
def factorial(n):
    if n <= 0:
        return 1
    else:
        return n*factorial(n-1)

# Taylor approximation at x0 of the function 'function'
def taylor(function,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (function.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# Plot results
def plot():
    x_lims = [-1,1]
    x1 = np.linspace(x_lims[0],x_lims[1],800)
    y1 = []
    # Approximate up until 10 starting from 1 and using steps of 2
    for j in range(1,5,1):
        func = taylor(f,0,j)
        print('Taylor expansion at n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label=str(j)+'. Ordnung')
        y1 = []
    # Plot the function to approximate (sine, in this case)
    plt.plot(x1,(1+x1)**(1/2),label=r'$\sqrt{1+x}$')
    plt.xlim(x_lims)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.savefig("Aufgabe_2b.pdf")
    plt.show()

plot()
# Out:
# Taylor expansion at n=1 0.5*x + 1
# Taylor expansion at n=2 -0.125*x**2 + 0.5*x + 1
# Taylor expansion at n=3 0.0625*x**3 - 0.125*x**2 + 0.5*x + 1
# Taylor expansion at n=4 -0.0390625*x**4 + 0.0625*x**3 - 0.125*x**2 + 0.5*x + 1

# %% [markdown]
# # Aufgabe 3

# %%
# Define the variable and the function to approximate
x = sy.Symbol('x')
f = exp(sin(x))

# Factorial function
def factorial(n):
    if n <= 0:
        return 1
    else:
        return n*factorial(n-1)

# Taylor approximation at x0 of the function 'function'
def taylor(function,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (function.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# Plot results
def plot():
    x_lims = [-20,20]
    x1 = np.linspace(x_lims[0],x_lims[1],800)
    y1 = []
    # Approximate up until 10 starting from 1 and using steps of 2
    for j in range(1,5,1):
        func = taylor(f,0,j)
        print('Taylor expansion at n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label=str(j)+'. Ordnung')
        y1 = []
    # Plot the function to approximate (sine, in this case)
    plt.plot(x1,np.exp(np.sin(x1)),label=r'$e^{\sin(x)}$')
    plt.xlim(x_lims)
    plt.ylim([-5,5])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.savefig("Aufgabe_3.pdf")
    plt.show()

plot()
# Out:
# Taylor expansion at n=1 x + 1
# Taylor expansion at n=2 x**2/2 + x + 1
# Taylor expansion at n=3 x**2/2 + x + 1
# Taylor expansion at n=4 -x**4/8 + x**2/2 + x + 1

# %% [markdown]
# # Aufgabe 4

# %%
# Define the variable and the function to approximate
x = sy.Symbol('x')
f = sin(x)

# Factorial function
def factorial(n):
    if n <= 0:
        return 1
    else:
        return n*factorial(n-1)

# Taylor approximation at x0 of the function 'function'
def taylor(function,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (function.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# Plot results
def plot():
    x_lims = [-10,10]
    x1 = np.linspace(x_lims[0],x_lims[1],800)
    y1 = []
    # Approximate up until 10 starting from 1 and using steps of 2
    for j in range(1,8,2):
        func = taylor(f,0,j)
        print('Taylor expansion at n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label=str(j)+'. Ordnung')
        y1 = []
    # Plot the function to approximate (sine, in this case)
    plt.plot(x1,np.sin(x1),label='sin(x)')
    plt.xlim(x_lims)
    plt.ylim([-5,5])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.savefig("Aufgabe_4a.pdf")
    plt.show()

plot()
# Out:
# Taylor expansion at n=1 x
# Taylor expansion at n=3 -x**3/6 + x
# Taylor expansion at n=5 x**5/120 - x**3/6 + x
# Taylor expansion at n=7 -x**7/5040 + x**5/120 - x**3/6 + x

# %%
# Define the variable and the function to approximate
x = sy.Symbol('x')
f = x*log(x)

# Factorial function
def factorial(n):
    if n <= 0:
        return 1
    else:
        return n*factorial(n-1)

# Taylor approximation at x0 of the function 'function'
def taylor(function,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (function.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# Plot results
def plot():
    x_lims = [0,10]
    x1 = np.linspace(x_lims[0],x_lims[1],800)
    y1 = []
    # Approximate up until 10 starting from 1 and using steps of 2
    for j in range(1,5,1):
        func = taylor(f,1,j)
        print('Taylor expansion at n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label=str(j)+'. Ordnung')
        y1 = []
    # Plot the function to approximate (sine, in this case)
    plt.plot(x1,x1*np.log(x1),label=r'$f(x)$')
    plt.xlim(x_lims)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.ylim(-5,5)
    plt.legend()
    plt.grid(True)
    plt.savefig("Aufgabe_4b.pdf")
    plt.show()

plot()
# Out:
# Taylor expansion at n=1 x - 1
# Taylor expansion at n=2 x + (x - 1)**2/2 - 1
# Taylor expansion at n=3 x - (x - 1)**3/6 + (x - 1)**2/2 - 1
# Taylor expansion at n=4 x + (x - 1)**4/12 - (x - 1)**3/6 + (x - 1)**2/2 - 1
# /home/lewis206/.local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in log
# /home/lewis206/.local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in multiply
